# %%
import pandas as pd

# %%
df = pd.read_csv('dat.csv')
df.sample(5)
# Out:
#             patientID   apptID gender  sched_date   appt_date  age  \
# 32107  12399433518654  5703646      M  2016-05-16  2016-05-20    2
# 53777  14177436814578  5665083      F  2016-05-05  2016-05-06   40
# 87171    797662271154  5768414      M  2016-06-03  2016-06-07   36
# 79290  82459919738999  5731184      F  2016-05-24  2016-06-08   36
# 22479   1472517283667  5634967      F  2016-04-28  2016-05-11   53
#
#           neighborhood  scholarship  hypertension  diabetes  alcoholism  \
# 32107     SÃO BENEDITO            0             0         0           0
# 53777         GURIGICA            1             0         0           0
# 87171      SANTA CLARA            0             0         0           0
# 79290  JARDIM DA PENHA            0             0         0           0
# 22479   GRANDE VITÓRIA            0             1         0           0
#
#        handicap  sms_received noshow  waiting
# 32107         0             0     No        4
# ...

# %%
df = df[['patientID', 'apptID', 'gender', 'age', 'neighborhood', 'scholarship', 'hypertension', 'diabetes', 'alcoholism', 'handicap', 'sched_date', 'appt_date', 'waiting', 'sms_received', 'noshow']]
df.sample(5)
# Out:
#              patientID   apptID gender  age      neighborhood  scholarship  \
# 50393    8581887329318  5692245      F   21         CONQUISTA            0
# 56514      21192916457  5716063      M   13    JARDIM CAMBURI            0
# 68655  692816993944563  5616924      M   21        CRUZAMENTO            0
# 76295   73456833923227  5764698      F   36            BONFIM            0
# 47864     914365529325  5625830      F   71  ILHA DO PRÍNCIPE            0
#
#        hypertension  diabetes  alcoholism  handicap  sched_date   appt_date  \
# 50393             0         0           0         0  2016-05-12  2016-05-12
# 56514             0         0           0         0  2016-05-18  2016-05-18
# 68655             0         0           0         0  2016-04-25  2016-05-12
# 76295             0         0           0         0  2016-06-02  2016-06-02
# 47864             0         0           0         0  2016-04-27  2016-05-04
#
#        waiting  sms_received noshow
# ...

# %%
df.to_csv('data.csv', index=False)
